# %%
import re
from typing import Any

from langchain_community.chat_models import ChatTongyi

# ruff: noqa: F401
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.tools import tool
from langchain_ollama.chat_models import ChatOllama

from citra.mcp.tool import get_connection

# %%
conn = get_connection()


@tool
def sql_outage(sql: str) -> str:
    """生成关于停电信息的sql查询语句。表结构：TABLE( \
        t_event_alarm_inter (equipName设备名称,lineName线路名称,faultType停电类型,\
        occurTime停电开始时间,endTime停电结束时间,
        gdsName 供电所单位名称，unitName供电公司名称)。详情只输出以上字段"""
    sql = sql.replace('`', '').replace('\\n', ' ')
    search = re.search(r'((select|SELECT)[^"]+)', sql)
    if search:
        return search.group()
    return ''


@tool
def sql_order_fault(sql: str) -> str:
    """生成关于工单故障的sql查询语句。表结构为 TABLE t_fault_order_inter (
    work_order_id 工单号,  received_time 受理时间,  address  地址,
    issue_description  受理内容,  phone_number 联系电话,  contact_person  联系人,
    analysis_result  分析结果,  order_type  工单类型,  unit_name  单位,
    power_supply_station 供电所）。详情只输出以上字段"""
    sql = sql.replace('`', '').replace('\\n', ' ')
    search = re.search(r'((select|SELECT)[^"]+)', sql)
    if search:
        return search.group()
    return ''

# %%
def to_markdown(cols: list, rows: tuple[tuple[Any, ...], ...]):
    if len(cols) != len(rows[0]):
        raise ValueError('列数和行数不匹配')
    yield '| ' + ' | '.join(cols) + ' |\n'
    yield '| ' + ' | '.join(['---'] * len(cols)) + ' |\n'
    for row in rows:
        yield '| ' + ' | '.join(str(cell) for cell in row) + ' |\n'


def str_to_gen(s: str, *, msg_type: str = 'msg', chunk_size: int = 10):
    """将字符串转换为生成器"""
    for i in range(0, len(s), chunk_size):
        yield s[i : i + chunk_size]


def execute_sql(sql: str):
    """执行sql语句，返回结果"""

    if sql == '':
        return '生成sql失败'
    with conn.cursor() as cursor:
        try:
            cursor.execute(sql)
            results = cursor.fetchall()
            if not results:
                yield '没有查询数据'
                return
            cols = [desc[0] for desc in cursor.description]
            yield from to_markdown(cols, results)
        except Exception as e:
            return f'执行sql失败: {e}'

# %%
# chatllm = ChatTongyi(model='qwen-max', temperature=0.7)
chatllm = ChatOllama(model='qwen2.5:3b', temperature=0.7)
tools = [sql_outage, sql_order_fault]

chat_with_tools = chatllm.bind_tools(tools)


def call_tools(msg: AIMessage) -> list[dict]:
    """Simple sequential tool calling helper."""
    tool_map = {tool.name: tool for tool in tools}
    tool_calls = msg.tool_calls.copy()
    for tool_call in tool_calls:
        tool_call['output'] = tool_map[tool_call['name']].invoke(tool_call['args'])
    return tool_calls


def ask_question(question: str):
    """问数据库问题"""
    try:
        ai_msg = chat_with_tools.invoke([HumanMessage(content=question)])
        if not ai_msg.tool_calls:
            print('没有调用工具')
            yield from str_to_gen(ai_msg.content)
        else:
            print('调用工具')
            query = call_tools(ai_msg)[0]['output']
            yield from execute_sql(query)
    except Exception as e:
        print(f'遇到错误: {e}')

# %%
for i in ask_question('请给出江山供电公司的故障信息'):
    print(i, end='')
# Out:
# 调用工具
# | work_order_id | received_time | address | issue_description | phone_number | contact_person | analysis_result | order_type | unit_name | power_supply_station |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 2505130435418982 | 2025-05-13 04:35:41 | 浙江省衢州市江山市石门镇东坑村88号 | 受理时间：2025-05-13 04:35:39，用户编号：，联系人：先生,联系电话：13867025042，故障地址：浙江省衢州市江山市石门镇东坑村88号，受理内容：一户无电。 | 13867025042 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 清漾供电所 |
# | 2505130442125808 | 2025-05-13 04:42:12 | 浙江省衢州市江山市峡口镇大峦口村东坑村88号 | 受理时间：2025-05-13 04:42:08，用户编号：，联系人：先生,联系电话：13867025042，故障地址：浙江省衢州市江山市峡口镇大峦口村东坑村88号，受理内容：一户无电。 | 13867025042 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单2张； | 外联故障工单 | 江山供电公司 | 峡口供电所 |
# | 2505130728071999 | 2025-05-13 07:28:07 | 浙江省衢州市江山市虎山街道江东社区江东大道江东五区小区109幢1单元302室 | 受理时间：2025-05-13 07:28:05，用户编号：3307710047787，联系人：江山市房地产管理处,联系电话：13587018406，故障地址：浙江省衢州市江山市虎山街道江东社区江东大道江东五区小区109幢1单元302室，受理内容：一户无电。 | 13587018406 | 江山市房地产管理处 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 区供电中心 |
# | 2505130815228996 | 2025-05-13 08:15:22 | 浙江省衢州市江山市上余镇李坪村樟树底边上 | 受理时间：2025-05-13 08:14:57，用户编号：，联系人：女士,联系电话：18657003930，故障地址：浙江省衢州市江山市上余镇李坪村樟树底边上，受理内容：一户无电。 | 18657003930 | 祝金良 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 须江供电所 |
# | 2505130837590174 | 2025-05-13 08:37:59 | 浙江省衢州市江山市贺村镇幸福行政村妙湾垄81号 | 受理时间：2025-05-13 08:37:54，用户编号：3307718001406，联系人：戴刚国,联系电话：15857033048，故障地址：浙江省衢州市江山市贺村镇幸福行政村妙湾垄81号，受理内容：一户无电。 | 15857033048 | 戴刚国 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505130841460022 | 2025-05-13 08:41:46 | 浙江省衢州市江山市贺村镇溪淤村山水坂12号 | 受理时间：2025-05-13 08:40:47，用户编号：，联系人：先生,联系电话：4552423，故障地址：，受理内容：电线掉落。 | 4552423 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单3张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505130930567367 | 2025-05-13 09:30:56 | 浙江省衢州市江山市长台镇贺新行政村义塘垄村6号 | 串户线掉落，需要处理。之前报修过还是没处理好 | 13511410100 | 徐日成 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 清漾供电所 |
# | 2505131000229555 | 2025-05-13 10:00:22 | 浙江省衢州市江山市石门镇西山行政村西山村地方 | 一户无电 | 17858551125 | 何树兴 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 清漾供电所 |
# | 2505131020018013 | 2025-05-13 10:20:01 | 浙江省衢州市江山市贺村镇莲华山工业园区莲花山工业园区名望家居 | 施工时电缆挖断了，需要现场核实是否属于供电产权 | 17357077223 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505131500305845 | 2025-05-13 15:00:30 | 浙江省衢州市江山市虎山街道 通达路1栋1单元501 | 受理时间：2025-05-13 14:58:55，用户编号：，联系人：先生,联系电话：13732519954，故障地址：，受理内容：一户无电。 | 13732519954 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单2张；3天内存在【虎山街道】地址，95598工单1张，数供工单6张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505131632127514 | 2025-05-13 16:32:12 | 浙江省衢州市江山市碗窑乡碗窑行政村鹿来村 | 一户无电 | 13735062647 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 须江供电所 |
# | 2025051380291943 | 2025-05-13 17:16:47 | 浙江省衢州市江山市贺村镇明星村门口垄54-1 | 【线路下垂】客户报修此处线路掉落在客户房顶，有危险，请联系尽快处理 | 18205812872 | 女士 | 【工单】近90天，该用户涉及95598工单1张，数供工单0张； | 95598故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505131810517348 | 2025-05-13 18:10:51 | 浙江省衢州市江山市石门镇达篷行政村小塘源新村油车坂小区71号充电桩 | 受理时间：2025-05-13 18:10:42，用户编号：3309939213032，联系人：刘德海,联系电话：15336721288，故障地址：浙江省衢州市江山市石门镇达篷行政村小塘源新村油车坂小区71号，受理内容：一户无电。 | 15336721288 | 刘德海 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 清漾供电所 |
# | 2505131814269454 | 2025-05-13 18:14:26 | 浙江省衢州市江山市虎山街道 下状元里43号 | 受理时间：2025-05-13 18:14:07，用户编号：，联系人：,联系电话：13757031913，故障地址：下状元里43号，受理内容：一户无电。 | 13757031913 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张；3天内存在【虎山街道】地址，95598工单1张，数供工单7张； | 外联故障工单 | 江山供电公司 | 区供电中心 |
# | 2505131816573533 | 2025-05-13 18:16:57 | 浙江省衢州市江山市凤林镇茅坂土菜馆对面 | 受理时间：2025-05-13 18:16:55，用户编号：3307720053313，联系人：周水旺,联系电话：13575985243，故障地址：浙江省衢州市江山市凤林镇茅坂土菜馆对面，受理内容：一户无电。 | 13575985243 | 周水旺 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张；3天内存在【凤林镇】地址，95598工单1张，数供工单5张； | 外联故障工单 | 江山供电公司 | 峡口供电所 |
# | 2505131835018980 | 2025-05-13 18:35:01 | 浙江省衢州市江山市新塘边镇乌鹰溪底姜机亮 | 受理时间：2025-05-13 18:34:31，用户编号：，联系人：女士,联系电话：17815878395，故障地址：浙江省衢州市江山市新塘边镇乌鹰溪底姜机亮，受理内容：一户无电。 | 17815878395 | 女士 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张；3天内存在【新塘边镇】地址，95598工单0张，数供工单6张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505131850309771 | 2025-05-13 18:50:30 | 浙江省衢州市江山市新塘边镇外坞村里坞63号 | 受理时间：2025-05-13 18:50:16，用户编号：undefined，联系人：姜志强,联系电话：18758959609，故障地址：浙江省衢州市江山市新塘边镇外坞村里坞63号，受理内容：一户无电。 | 18758959609 | 姜志强 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张；3天内存在【外坞村】地址，95598工单0张，数供工单2张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505131906555916 | 2025-05-13 19:06:55 | 浙江省衢州市江山市上余镇上余行政村上余地方 | 受理时间：2025-05-13 19:06:06，用户编号：3307718202662，联系人：余乾理,联系电话：15869063377，故障地址：浙江省衢州市江山市上余镇上余行政村上余地方，受理内容：电线掉落有安全隐患。 | 15869063377 | 余乾理 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 须江供电所 |
# | 2505131926532960 | 2025-05-13 19:26:53 | 浙江省衢州市江山市石门镇江郎山行政村泉井村6号 | 受理时间：2025-05-13 19:26:40，用户编号：3307718317862，联系人：徐江法,联系电话：15700023100，故障地址：浙江省衢州市江山市石门镇江郎山行政村泉井村6号，受理内容：一户无电。 | 15700023100 | 徐江法 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 清漾供电所 |
# | 2505131932396180 | 2025-05-13 19:32:39 | 浙江省衢州市江山市廿八都镇山峰村沿下5号 | 受理时间：2025-05-13 19:32:23，用户编号：，联系人：先生,联系电话：15726998603，故障地址：浙江省衢州市江山市廿八都镇山峰村沿下5号，受理内容：一户无电。 | 15726998603 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 峡口供电所 |
# | 2505131936131928 | 2025-05-13 19:36:13 | 浙江省衢州市江山市虎山街道金坞行政村下里坞自然村87号 | 受理时间：2025-05-13 19:35:46，用户编号：3307718028216，联系人：金国忠,联系电话：15857002585，故障地址：浙江省衢州市江山市虎山街道金坞行政村下里坞自然村87号，受理内容：一户无电。 | 15857002585 | 金国忠 | 【工单】近90天，该用户涉及95598工单0张，数供工单2张； | 外联故障工单 | 江山供电公司 | 须江供电所 |
# | 2505131946475175 | 2025-05-13 19:46:47 | 浙江省衢州市江山市虎山街道虎山一街44号 | 受理时间：2025-05-13 19:46:05，用户编号：，联系人：女士,联系电话：13867027854，故障地址：浙江省衢州市江山市虎山街道虎山一街44号，受理内容：一户无电。 | 13867027854 | 女士 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 区供电中心 |
# | 2505131957438849 | 2025-05-13 19:57:43 | 浙江省衢州市江山市上余镇李坪行政村平坦村 | 受理时间：2025-05-13 19:57:37，用户编号：3307710044265，联系人：邹效喜,联系电话：13567086379，故障地址：浙江省衢州市江山市上余镇李坪行政村平坦村，受理内容：一户无电。 | 13567086379 | 邹效喜 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 须江供电所 |
# | 2505132040046686 | 2025-05-13 20:40:04 | 浙江省衢州市江山市坛石镇敖头41号 | 受理时间：2025-05-13 20:40:02，用户编号：，联系人：女士,联系电话：15372013352，故障地址：浙江省衢州市江山市坛石镇敖头41号，受理内容：一户无电。 | 15372013352 | 女士 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张；3天内存在【坛石镇】地址，95598工单0张，数供工单3张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505132045079511 | 2025-05-13 20:45:06 | 浙江省衢州市江山市峡口镇迎福路338号 | 受理时间：2025-05-13 20:45:01，用户编号：3307710013023，联系人：毛晓明,联系电话：15215706201，故障地址：浙江省衢州市江山市峡口镇迎福路338号，受理内容：一户无电。 | 15215706201 | 毛晓明 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 峡口供电所 |
# | 2505132307124222 | 2025-05-13 23:07:12 | 浙江省衢州市江山市虎山街道 南一街65幢703室 | 受理时间：2025-05-13 23:06:51，用户编号：，联系人：先生,联系电话：13587012259，故障地址：浙江省衢州市江山市虎山街道 南一街65幢703室，受理内容：电压不稳 | 13587012259 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张；3天内存在【虎山街道】地址，95598工单1张，数供工单8张； | 外联故障工单 | 江山供电公司 | 区供电中心 |
# | 2505132312413178 | 2025-05-13 23:12:41 | 浙江省衢州市江山市虎山街道 店前村11号 | 受理时间：2025-05-13 23:12:39，用户编号：，联系人：先生,联系电话：13867025248，故障地址：浙江省衢州市江山市虎山街道 店前村11号，受理内容：一户无电。 | 13867025248 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单2张；3天内存在【虎山街道】地址，95598工单1张，数供工单9张； | 外联故障工单 | 江山供电公司 | 须江供电所 |
# | 2025051380380181 | 2025-05-13 23:13:25 | 浙江省衢州市江山市南一街65号楼702室 | 【电能质量】客户报修一户电压[不稳]，电器无法正常使用，请处理。 | 13857020762 | 女士 | 【工单】近90天，该用户涉及95598工单1张，数供工单2张； | 95598故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505140545314730 | 2025-05-14 05:45:31 | 浙江省衢州市江山市贺村镇高路村66号 | 受理时间：2025-05-14 05:45:27，用户编号：，联系人：先生,联系电话：15924068232，故障地址：浙江省衢州市江山市贺村镇高路村66号，受理内容：一户无电。 | 15924068232 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505140719202351 | 2025-05-14 07:19:20 | 浙江省衢州市江山市坛石镇郭丰坞行政村后垄地方 | 受理时间：2025-05-14 07:19:18，用户编号：3307718009264，联系人：谢方清,联系电话：13587017189，故障地址：浙江省衢州市江山市坛石镇郭丰坞行政村后垄地方，受理内容：一户无电。 | 13587017189 | 谢方清 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505140738226621 | 2025-05-14 07:38:22 | 浙江省衢州市江山市清湖街道贺仓村86号 | 受理时间：2025-05-14 07:38:02，用户编号：3307720152486，联系人：毛华君,联系电话：18757021606，故障地址：浙江省衢州市江山市清湖街道贺仓村86号，受理内容：用电异常。 | 18757021606 | 毛华君 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张；3天内存在【贺仓村】地址，95598工单0张，数供工单2张； | 外联故障工单 | 江山供电公司 | 清漾供电所 |
# | 2505140758462465 | 2025-05-14 07:58:46 | 浙江省衢州市江山市清湖贺仓毛小娟 | 受理时间：2025-05-14 07:58:43，用户编号：，联系人：先生,联系电话：15268095509，故障地址：浙江省衢州市江山市清湖贺仓毛小娟，受理内容：一户无电。 | 15268095509 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 清漾供电所 |
# | 2505140820223124 | 2025-05-14 08:20:21 | 浙江省衢州市江山市坛石镇占塘村长山弄地方16号 | 受理时间：2025-05-14 08:20:17，用户编号：，联系人：女士,联系电话：13567038083，故障地址：浙江省衢州市江山市坛石镇占塘村长山弄地方16号，受理内容：一户无电。 | 13567038083 | 女士 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505140835492460 | 2025-05-14 08:35:49 | 浙江省衢州市江山市贺村镇山底行政村家坞山2号 | 受理时间：2025-05-14 08:35:28，用户编号：3307718260191，联系人：周辛耕,联系电话：13587128338，故障地址：浙江省衢州市江山市贺村镇山底行政村家坞山2号，受理内容：一户无电。 | 13587128338 | 周辛耕 | 【工单】近90天，该用户涉及95598工单0张，数供工单2张；3天内存在【山底行政村】地址，95598工单0张，数供工单2张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505140907388710 | 2025-05-14 09:07:38 | 浙江省衢州市江山市大陈乡乌龙村 | 受理时间：2025-05-14 09:07:36，用户编号：，联系人：先生,联系电话：13567010512，故障地址：浙江省衢州市江山市大陈乡乌龙村，受理内容：多户无电。 | 13567010512 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 须江供电所 |
# | 2505140909127660 | 2025-05-14 09:09:12 | 浙江省衢州市江山市双塔街道前召村5号 | 受理时间：2025-05-14 09:09:08，用户编号：，联系人：先生,联系电话：15867019399，故障地址：浙江省衢州市江山市双塔街道前召村5号，受理内容：一户无电。 | 15867019399 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 须江供电所 |
# | 2505140910510424 | 2025-05-14 09:10:51 | 浙江省衢州市江山市坛石镇横渡行政村中心村 | 进线烧掉要求更换 | 13567018418 | 先生 | 【工单】近90天，该用户涉及95598工单0张，数供工单1张； | 外联故障工单 | 江山供电公司 | 贺村供电所 |
# | 2505140942260316 | 2025-05-14 09:42:26 | 浙江省衢州市江山市峡口镇峡南行政村上西坑71号 | 一户无电。 | 13867006173 | 谢东生 | 【工单】近90天，该用户涉及95598工单0张，数供工单2张； | 外联故障工单 | 江山供电公司 | 峡口供电所 |
